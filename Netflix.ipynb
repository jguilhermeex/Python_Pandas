# %% [markdown]
# # Análise Exploratória - Netflix

# %% [markdown]
# O objetivo deste projeto é analisar um dataset da Netflix para demonstrar meus conhecimentos na linguagem Python, especialmente na biblioteca Pandas, na qual estou estudando nos últimos tempos.  Caso tenha algum feedback, não hesite, me chame no Linkedin! :)

# %% [markdown]
# <img src ='netflix.jpg'>

# %% [markdown]
# ## Importando e entendendo dos dados

# %%
#Importando o pandas

import pandas as pd

#importando a base de dados

netflix= pd.read_csv(r'C:\Users\José Guilherme\Downloads\Curso Python GRINGO\DataAnalysis\data\netflix_titles.csv', sep ='|')
netflix
# Out:
#       Unnamed: 0 show_id     type                  title         director  \
# 0              0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1              1      s2  TV Show          Blood & Water              NaN
# 2              2      s3  TV Show              Ganglands  Julien Leclercq
# 3              3      s4  TV Show  Jailbirds New Orleans              NaN
# 4              4      s5  TV Show           Kota Factory              NaN
# ...          ...     ...      ...                    ...              ...
# 8802        8802   s8803    Movie                 Zodiac    David Fincher
# 8803        8803   s8804  TV Show            Zombie Dumb              NaN
# 8804        8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805        8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806        8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# ...

# %%
#Amostra dos dados
netflix.head(20)
# Out:
#     Unnamed: 0 show_id     type  \
# 0            0      s1    Movie
# 1            1      s2  TV Show
# 2            2      s3  TV Show
# 3            3      s4  TV Show
# 4            4      s5  TV Show
# 5            5      s6  TV Show
# 6            6      s7    Movie
# 7            7      s8    Movie
# 8            8      s9  TV Show
# 9            9     s10    Movie
# 10          10     s11  TV Show
# 11          11     s12  TV Show
# 12          12     s13    Movie
# 13          13     s14    Movie
# 14          14     s15  TV Show
# 15          15     s16  TV Show
# 16          16     s17    Movie
# 17          17     s18  TV Show
# 18          18     s19    Movie
# 19          19     s20  TV Show
#
#                                                 title  \
# 0                                Dick Johnson Is Dead
# 1                                       Blood & Water
# 2                                           Ganglands
# ...

# %%
netflix.tail()
# Out:
#       Unnamed: 0 show_id     type        title         director  \
# 8802        8802   s8803    Movie       Zodiac    David Fincher
# 8803        8803   s8804  TV Show  Zombie Dumb              NaN
# 8804        8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805        8805   s8806    Movie         Zoom     Peter Hewitt
# 8806        8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# ...

# %%
#Verificando o número de linhas e colunas
netflix.shape
# Out:
# (8807, 13)

# %%
#Colunas
netflix.columns
# Out:
# Index(['Unnamed: 0', 'show_id', 'type', 'title', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in',
#        'description'],
#       dtype='object')

# %%
#Verificando mais informações dos dados. 
#Nota-se que em algumas colunas os valores estão com divergência, indicando valores ausentes.
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    8807 non-null   int64
#  1   show_id       8807 non-null   object
#  2   type          8807 non-null   object
#  3   title         8807 non-null   object
#  4   director      6173 non-null   object
#  5   cast          7982 non-null   object
#  6   country       7976 non-null   object
#  7   date_added    8797 non-null   object
#  8   release_year  8807 non-null   int64
#  9   rating        8803 non-null   object
#  10  duration      8804 non-null   object
#  11  listed_in     8807 non-null   object
#  12  description   8807 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 894.6+ KB

# %%
#Dados numéricos
netflix.describe()
# Out:
#         Unnamed: 0  release_year
# count  8807.000000   8807.000000
# mean   4403.000000   2014.180198
# std    2542.506244      8.819312
# min       0.000000   1925.000000
# 25%    2201.500000   2013.000000
# 50%    4403.000000   2017.000000
# 75%    6604.500000   2019.000000
# max    8806.000000   2021.000000

# %%
#Dados categóricos
netflix.describe(include = object)
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# ...

# %% [markdown]
# ## Preparando os dados
#
# - Retirando colunas irrelevantes
# - Identificar a existência de linhas duplicadas
# - Renomear colunas para melhor entendimento
# - Tratamento de valores ausentes (missing values).

# %%
#Removendo a coluna Unnamed
netflix.drop(['Unnamed: 0'], axis = 1, inplace = True)
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Checando linhas duplicadas
netflix.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Length: 8807, dtype: bool

# %%
# Checando linhas duplicadas
netflix.duplicated().sum()
# Out:
# 0

# %%
#Renomeando a coluna listed_in
netflix.rename(columns = {'listed_in' : 'categories'}, inplace=True)
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# categories         0
# description        0
# dtype: int64

# %%
netflix.isnull().sum()
netflix.shape
#Removi os valores ausentes das colunas rating, duration e date_added pois possuiam quantidades irrelevantes.
netflix.dropna(subset = ['rating','duration','date_added'], inplace = True)
netflix.isnull().sum()
#A coluna director possuia um alto indice de valores ausentes, optei por remove-la.
#Preenchi as outras com Unknown para não enviesar os dados.
(netflix['cast'].isnull().sum() / netflix['show_id'].count()) * 100
#9% de valores ausentes
(netflix['country'].isnull().sum() / netflix['show_id'].count()) * 100
#9% de valores ausentes
(netflix['director'].isnull().sum() / netflix['show_id'].count()) * 100
#29% de valores ausentes

netflix['cast'].fillna(value = 'Unknown', inplace = True)
netflix['country'].fillna(value = 'Unknown', inplace = True)
netflix.drop(columns =['director'], inplace = True)
netflix.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# categories      0
# description     0
# dtype: int64

# %%
#checando novamente os dados
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8790 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   cast          8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   categories    8790 non-null   object
#  10  description   8790 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 824.1+ KB

# %% [markdown]
# # Analisando as variáveis mais de perto

# %%
#Analisei o numero de produções por país e os Estados Unidos aparece bem a frente de todos os outros
ax = netflix['country'].value_counts().head(10).plot(figsize =(15,5),\
title ='Número de Países Com Mais Produções da Netflix',kind ='bar', color = 'green')
ax.set_xlabel('Países')
ax.set_ylabel('Contagem')
# Out:
# Text(0, 0.5, 'Contagem')

# %%
#Existem mais filmes do que séries no catálogo da netflix
colors = ['#0089ba','#f9f871']
netflix['type'].value_counts().plot(figsize =(20,6),\
title ='Porcentagem de Séries e Filmes no catálogo d Netflix',kind = 'pie', \
legend =True, autopct='%1.1f%%', ylabel ='', colors=colors)
# Out:
# <AxesSubplot:title={'center':'Porcentagem de Séries e Filmes no catálogo d Netflix'}>

# %%
#Houve uma queda expressiva no número de produções nos últimos anos.
netflix.groupby('release_year')['show_id'].count().tail(10).plot(figsize =(15,5),\
xlabel='Anos',title = 'Produções ao Longo do Tempo', ylabel ='Número de Produções',linewidth=3, color ='blue')
# Out:
# <AxesSubplot:title={'center':'Produções ao Longo do Tempo'}, xlabel='Anos', ylabel='Número de Produções'>
